# %%
# Only enable critical logging (Optional)
import os
os.environ["PYCARET_CUSTOM_LOGGING_LEVEL"] = "CRITICAL"
def what_is_installed():
    from pycaret import show_versions
    show_versions()

try:
    what_is_installed()
except ModuleNotFoundError:
    print('exception')
    # !pip install pycaret
    # !pip install pycaret-ts-alpha
    what_is_installed()
# Out:
# Requirement already satisfied: pycaret in c:\python\lib\site-packages (2.3.10)
# Requirement already satisfied: wordcloud in c:\python\lib\site-packages (from pycaret) (1.8.2.2)
# Requirement already satisfied: spacy<2.4.0 in c:\python\lib\site-packages (from pycaret) (2.3.9)
# Requirement already satisfied: umap-learn in c:\python\lib\site-packages (from pycaret) (0.5.3)
# Requirement already satisfied: mlxtend>=0.17.0 in c:\python\lib\site-packages (from pycaret) (0.19.0)
# Collecting numba<0.55
#   Using cached numba-0.54.1-cp38-cp38-win_amd64.whl (2.3 MB)
# Requirement already satisfied: ipywidgets in c:\python\lib\site-packages (from pycaret) (8.0.4)
# Requirement already satisfied: nltk in c:\python\lib\site-packages (from pycaret) (3.8.1)
# Requirement already satisfied: cufflinks>=0.17.0 in c:\python\lib\site-packages (from pycaret) (0.17.3)
# Requirement already satisfied: mlflow in c:\python\lib\site-packages (from pycaret) (2.1.1)
# Collecting imbalanced-learn==0.7.0
#   Using cached imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
# Requirement already satisfied: IPython in c:\python\lib\site-packages (from pycaret) (8.10.0)
# Requirement already satisfied: scikit-plot in c:\python\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python38\site-packages (from pycaret) (1.4.4)
# Requirement already satisfied: pyLDAvis in c:\python\lib\site-packages (from pycaret) (3.3.1)
# Requirement already satisfied: Boruta in c:\python\lib\site-packages (from pycaret) (0.3)
# Collecting scikit-learn==0.23.2
#   Using cached scikit_learn-0.23.2-cp38-cp38-win_amd64.whl (6.8 MB)
# Requirement already satisfied: pyyaml<6.0.0 in c:\python\lib\site-packages (from pycaret) (5.4.1)
# Requirement already satisfied: matplotlib in c:\python\lib\site-packages (from pycaret) (3.6.3)
# Requirement already satisfied: kmodes>=0.10.1 in c:\python\lib\site-packages (from pycaret) (0.12.2)
# Requirement already satisfied: pandas-profiling>=2.8.0 in c:\python\lib\site-packages (from pycaret) (3.6.6)
# Requirement already satisfied: joblib in c:\users\user\appdata\roaming\python\python38\site-packages (from pycaret) (1.0.1)
# Requirement already satisfied: yellowbrick>=1.0.1 in c:\users\user\appdata\roaming\python\python38\site-packages (from pycaret) (1.5)
# Requirement already satisfied: pyod in c:\python\lib\site-packages (from pycaret) (1.0.7)
# Collecting scipy<=1.5.4
#   Using cached scipy-1.5.4-cp38-cp38-win_amd64.whl (31.4 MB)
# Requirement already satisfied: textblob in c:\python\lib\site-packages (from pycaret) (0.17.1)
# Requirement already satisfied: seaborn in c:\python\lib\site-packages (from pycaret) (0.12.2)
# Requirement already satisfied: lightgbm>=2.3.1 in c:\python\lib\site-packages (from pycaret) (3.3.5)
# Requirement already satisfied: gensim<4.0.0 in c:\python\lib\site-packages (from pycaret) (3.8.3)
# Requirement already satisfied: plotly>=4.4.1 in c:\python\lib\site-packages (from pycaret) (5.13.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\python\lib\site-packages (from imbalanced-learn==0.7.0->pycaret) (1.21.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python\lib\site-packages (from scikit-learn==0.23.2->pycaret) (3.1.0)
# Requirement already satisfied: six>=1.9.0 in c:\python\lib\site-packages (from cufflinks>=0.17.0->pycaret) (1.16.0)
# Requirement already satisfied: colorlover>=0.2.1 in c:\python\lib\site-packages (from cufflinks>=0.17.0->pycaret) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in c:\python\lib\site-packages (from cufflinks>=0.17.0->pycaret) (65.6.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\python\lib\site-packages (from gensim<4.0.0->pycaret) (6.3.0)
# Requirement already satisfied: Cython==0.29.14 in c:\python\lib\site-packages (from gensim<4.0.0->pycaret) (0.29.14)
# Requirement already satisfied: matplotlib-inline in c:\python\lib\site-packages (from IPython->pycaret) (0.1.6)
# Requirement already satisfied: stack-data in c:\python\lib\site-packages (from IPython->pycaret) (0.6.2)
# Requirement already satisfied: backcall in c:\python\lib\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: pickleshare in c:\python\lib\site-packages (from IPython->pycaret) (0.7.5)
# Requirement already satisfied: colorama in c:\python\lib\site-packages (from IPython->pycaret) (0.4.6)
# Requirement already satisfied: jedi>=0.16 in c:\python\lib\site-packages (from IPython->pycaret) (0.18.2)
# Requirement already satisfied: decorator in c:\python\lib\site-packages (from IPython->pycaret) (5.1.1)
# Requirement already satisfied: traitlets>=5 in c:\python\lib\site-packages (from IPython->pycaret) (5.9.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\python\lib\site-packages (from IPython->pycaret) (2.14.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\python\lib\site-packages (from IPython->pycaret) (3.0.37)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\python\lib\site-packages (from ipywidgets->pycaret) (6.21.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\python\lib\site-packages (from ipywidgets->pycaret) (3.0.5)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\python\lib\site-packages (from ipywidgets->pycaret) (4.0.5)
# Requirement already satisfied: wheel in c:\python\lib\site-packages (from lightgbm>=2.3.1->pycaret) (0.38.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python\lib\site-packages (from matplotlib->pycaret) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\python\lib\site-packages (from matplotlib->pycaret) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python\lib\site-packages (from matplotlib->pycaret) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python\lib\site-packages (from matplotlib->pycaret) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\python\lib\site-packages (from matplotlib->pycaret) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python\lib\site-packages (from matplotlib->pycaret) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python\lib\site-packages (from matplotlib->pycaret) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\python\lib\site-packages (from matplotlib->pycaret) (22.0)
# Collecting numpy>=1.13.3
#   Using cached numpy-1.20.3-cp38-cp38-win_amd64.whl (13.7 MB)
# Collecting llvmlite<0.38,>=0.37.0rc1
#   Using cached llvmlite-0.37.0-cp38-cp38-win_amd64.whl (17.0 MB)
# Requirement already satisfied: pytz>=2020.1 in c:\python\lib\site-packages (from pandas->pycaret) (2022.6)
# Requirement already satisfied: ydata-profiling in c:\python\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (4.0.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\python\lib\site-packages (from plotly>=4.4.1->pycaret) (8.2.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\python\lib\site-packages (from spacy<2.4.0->pycaret) (0.7.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\python\lib\site-packages (from spacy<2.4.0->pycaret) (3.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\python\lib\site-packages (from spacy<2.4.0->pycaret) (2.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\python\lib\site-packages (from spacy<2.4.0->pycaret) (0.10.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\python\lib\site-packages (from spacy<2.4.0->pycaret) (4.64.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\python\lib\site-packages (from spacy<2.4.0->pycaret) (1.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\python\lib\site-packages (from spacy<2.4.0->pycaret) (1.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\python\lib\site-packages (from spacy<2.4.0->pycaret) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\python\lib\site-packages (from spacy<2.4.0->pycaret) (1.0.9)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\python\lib\site-packages (from spacy<2.4.0->pycaret) (7.4.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\python\lib\site-packages (from spacy<2.4.0->pycaret) (2.28.1)
# Collecting yellowbrick>=1.0.1
#   Using cached yellowbrick-1.4-py3-none-any.whl (274 kB)
#   Using cached yellowbrick-1.3.post1-py3-none-any.whl (271 kB)
# Collecting numpy>=1.13.3
#   Downloading numpy-1.19.5-cp38-cp38-win_amd64.whl (13.3 MB)
#      ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#      - -------------------------------------- 0.4/13.3 MB 8.1 MB/s eta 0:00:02
#      -- ------------------------------------- 1.0/13.3 MB 10.2 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.5/13.3 MB 10.7 MB/s eta 0:00:02
#      ------ --------------------------------- 2.1/13.3 MB 11.3 MB/s eta 0:00:01
#      -------- ------------------------------- 2.8/13.3 MB 11.8 MB/s eta 0:00:01
#      ---------- ----------------------------- 3.4/13.3 MB 11.9 MB/s eta 0:00:01
#      ----------- ---------------------------- 3.9/13.3 MB 11.8 MB/s eta 0:00:01
#      ------------- -------------------------- 4.4/13.3 MB 11.6 MB/s eta 0:00:01
#      --------------- ------------------------ 5.0/13.3 MB 11.9 MB/s eta 0:00:01
#      ---------------- ----------------------- 5.6/13.3 MB 11.9 MB/s eta 0:00:01
#      ------------------ --------------------- 6.2/13.3 MB 12.0 MB/s eta 0:00:01
#      -------------------- ------------------- 6.8/13.3 MB 12.1 MB/s eta 0:00:01
#      ---------------------- ----------------- 7.4/13.3 MB 12.1 MB/s eta 0:00:01
#      ----------------------- ---------------- 7.9/13.3 MB 11.9 MB/s eta 0:00:01
#      ------------------------- -------------- 8.5/13.3 MB 12.1 MB/s eta 0:00:01
#      --------------------------- ------------ 9.0/13.3 MB 12.0 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.6/13.3 MB 12.1 MB/s eta 0:00:01
#      ------------------------------ -------- 10.2/13.3 MB 12.1 MB/s eta 0:00:01
#      ------------------------------- ------- 10.8/13.3 MB 12.6 MB/s eta 0:00:01
#      --------------------------------- ----- 11.4/13.3 MB 12.6 MB/s eta 0:00:01
#      ---------------------------------- ---- 11.9/13.3 MB 12.4 MB/s eta 0:00:01
#      ------------------------------------ -- 12.4/13.3 MB 12.4 MB/s eta 0:00:01
#      --------------------------------------  13.0/13.3 MB 12.1 MB/s eta 0:00:01
#      --------------------------------------  13.3/13.3 MB 12.4 MB/s eta 0:00:01
#      --------------------------------------- 13.3/13.3 MB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: docker<7,>=4.0.0 in c:\python\lib\site-packages (from mlflow->pycaret) (6.0.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\python\lib\site-packages (from mlflow->pycaret) (4.22.0)
# Requirement already satisfied: cloudpickle<3 in c:\python\lib\site-packages (from mlflow->pycaret) (2.2.1)
# Requirement already satisfied: click<9,>=7.0 in c:\python\lib\site-packages (from mlflow->pycaret) (8.1.3)
# Requirement already satisfied: alembic<2 in c:\python\lib\site-packages (from mlflow->pycaret) (1.9.4)
# Requirement already satisfied: markdown<4,>=3.3 in c:\python\lib\site-packages (from mlflow->pycaret) (3.4.1)
# Requirement already satisfied: gitpython<4,>=2.1.0 in c:\python\lib\site-packages (from mlflow->pycaret) (3.1.31)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\python\lib\site-packages (from mlflow->pycaret) (3.1.2)
# Requirement already satisfied: querystring-parser<2 in c:\python\lib\site-packages (from mlflow->pycaret) (1.2.4)
# Requirement already satisfied: waitress<3 in c:\python\lib\site-packages (from mlflow->pycaret) (2.1.2)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\python\lib\site-packages (from mlflow->pycaret) (0.4.3)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in c:\python\lib\site-packages (from mlflow->pycaret) (0.17.4)
# Requirement already satisfied: pyarrow<11,>=4.0.0 in c:\python\lib\site-packages (from mlflow->pycaret) (10.0.1)
# Requirement already satisfied: Flask<3 in c:\python\lib\site-packages (from mlflow->pycaret) (2.2.3)
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in c:\python\lib\site-packages (from mlflow->pycaret) (1.4.46)
# Requirement already satisfied: shap<1,>=0.40 in c:\python\lib\site-packages (from mlflow->pycaret) (0.41.0)
# Requirement already satisfied: importlib-metadata!=4.7.0,<6,>=3.7.0 in c:\python\lib\site-packages (from mlflow->pycaret) (5.2.0)
# Requirement already satisfied: entrypoints<1 in c:\python\lib\site-packages (from mlflow->pycaret) (0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\python\lib\site-packages (from nltk->pycaret) (2022.10.31)
# Requirement already satisfied: funcy in c:\python\lib\site-packages (from pyLDAvis->pycaret) (1.18)
# Requirement already satisfied: future in c:\python\lib\site-packages (from pyLDAvis->pycaret) (0.18.3)
# Requirement already satisfied: numexpr in c:\python\lib\site-packages (from pyLDAvis->pycaret) (2.8.4)
# Collecting pyLDAvis
#   Using cached pyLDAvis-3.4.0-py3-none-any.whl (2.6 MB)
#   Downloading pyLDAvis-3.3.0.tar.gz (1.7 MB)
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      -------------- ------------------------- 0.6/1.7 MB 12.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.2/1.7 MB 13.1 MB/s eta 0:00:01
#      ---------------------------------------- 1.7/1.7 MB 11.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#   Downloading pyLDAvis-3.2.2.tar.gz (1.7 MB)
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      ---------- ----------------------------- 0.5/1.7 MB 13.8 MB/s eta 0:00:01
#      ----------------------- ---------------- 1.0/1.7 MB 12.5 MB/s eta 0:00:01
#      ---------------------------------------- 1.7/1.7 MB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: statsmodels in c:\python\lib\site-packages (from pyod->pycaret) (0.13.5)
# Requirement already satisfied: pynndescent>=0.5 in c:\python\lib\site-packages (from umap-learn->pycaret) (0.5.8)
# Requirement already satisfied: importlib-resources in c:\python\lib\site-packages (from alembic<2->mlflow->pycaret) (5.12.0)
# Requirement already satisfied: Mako in c:\python\lib\site-packages (from alembic<2->mlflow->pycaret) (1.2.4)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\python\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret) (2.6.0)
# Requirement already satisfied: oauthlib>=3.1.0 in c:\python\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in c:\python\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret) (0.9.0)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\python\lib\site-packages (from docker<7,>=4.0.0->mlflow->pycaret) (1.5.1)
# Requirement already satisfied: urllib3>=1.26.0 in c:\python\lib\site-packages (from docker<7,>=4.0.0->mlflow->pycaret) (1.26.12)
# Requirement already satisfied: pywin32>=304 in c:\python\lib\site-packages (from docker<7,>=4.0.0->mlflow->pycaret) (305)
# Requirement already satisfied: itsdangerous>=2.0 in c:\python\lib\site-packages (from Flask<3->mlflow->pycaret) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\python\lib\site-packages (from Flask<3->mlflow->pycaret) (2.2.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\python\lib\site-packages (from gitpython<4,>=2.1.0->mlflow->pycaret) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in c:\python\lib\site-packages (from importlib-metadata!=4.7.0,<6,>=3.7.0->mlflow->pycaret) (3.14.0)
# Requirement already satisfied: tornado>=6.1 in c:\python\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\python\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (5.2.0)
# Requirement already satisfied: nest-asyncio in c:\python\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.5.6)
# Requirement already satisfied: pyzmq>=20 in c:\python\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (25.0.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\python\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (8.0.3)
# Requirement already satisfied: psutil in c:\python\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (5.9.4)
# Requirement already satisfied: comm>=0.1.1 in c:\python\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\python\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.6.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\python\lib\site-packages (from jedi>=0.16->IPython->pycaret) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python\lib\site-packages (from Jinja2<4,>=3.0->mlflow->pycaret) (2.1.2)
# Requirement already satisfied: wcwidth in c:\python\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->IPython->pycaret) (0.2.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\python\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret) (2022.9.24)
# Requirement already satisfied: slicer==0.0.7 in c:\python\lib\site-packages (from shap<1,>=0.40->mlflow->pycaret) (0.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in c:\python\lib\site-packages (from sqlalchemy<2,>=1.4.0->mlflow->pycaret) (2.0.2)
# Requirement already satisfied: executing>=1.2.0 in c:\python\lib\site-packages (from stack-data->IPython->pycaret) (1.2.0)
# Requirement already satisfied: pure-eval in c:\python\lib\site-packages (from stack-data->IPython->pycaret) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in c:\python\lib\site-packages (from stack-data->IPython->pycaret) (2.2.1)
# Requirement already satisfied: patsy>=0.5.2 in c:\python\lib\site-packages (from statsmodels->pyod->pycaret) (0.5.3)
# Requirement already satisfied: multimethod<1.10,>=1.4 in c:\python\lib\site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret) (1.9.1)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\python\lib\site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret) (0.12.3)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in c:\python\lib\site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret) (2.13.3)
# Requirement already satisfied: htmlmin==0.1.12 in c:\python\lib\site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret) (0.1.12)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in c:\python\lib\site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret) (1.10.5)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\python\lib\site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret) (0.7.5)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\python\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret) (0.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\python\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret) (3.0)
# Requirement already satisfied: attrs>=19.3.0 in c:\python\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret) (22.1.0)
# Requirement already satisfied: imagehash in c:\python\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret) (4.3.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\python\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow->pycaret) (5.0.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\python\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->pycaret) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\python\lib\site-packages (from pydantic<1.11,>=1.8.1->ydata-profiling->pandas-profiling>=2.8.0->pycaret) (4.5.0)
# Requirement already satisfied: PyWavelets in c:\python\lib\site-packages (from imagehash->visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret) (1.4.1)
# Building wheels for collected packages: pyLDAvis
#   Building wheel for pyLDAvis (setup.py): started
#   Building wheel for pyLDAvis (setup.py): finished with status 'done'
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.2.2-py2.py3-none-any.whl size=135611 sha256=29391eb53bc4d1b2c5bdcc02a92af89284bee6a21ea14e7f996eb291bbbec62f
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\2a\5b\b3\26b52781cdeea9c815e147cfd4ac4a0a3472bce92142115670
# Successfully built pyLDAvis
# Installing collected packages: numpy, llvmlite, scipy, numba, scikit-learn, pyLDAvis, yellowbrick, imbalanced-learn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.38.1
#     Uninstalling llvmlite-0.38.1:
#       Successfully uninstalled llvmlite-0.38.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: numba
#     Found existing installation: numba 0.55.2
#     Uninstalling numba-0.55.2:
#       Successfully uninstalled numba-0.55.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.3
#     Uninstalling scikit-learn-1.1.3:
#       Successfully uninstalled scikit-learn-1.1.3
#   Attempting uninstall: pyLDAvis
#     Found existing installation: pyLDAvis 3.3.1
#     Uninstalling pyLDAvis-3.3.1:
#       Successfully uninstalled pyLDAvis-3.3.1
#   Attempting uninstall: yellowbrick
#     Found existing installation: yellowbrick 1.5
#     Uninstalling yellowbrick-1.5:
#       Successfully uninstalled yellowbrick-1.5
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.9.1
#     Uninstalling imbalanced-learn-0.9.1:
#       Successfully uninstalled imbalanced-learn-0.9.1
# Successfully installed imbalanced-learn-0.7.0 llvmlite-0.37.0 numba-0.54.1 numpy-1.19.5 pyLDAvis-3.2.2 scikit-learn-0.23.2 scipy-1.5.4 yellowbrick-1.3.post1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sktime 0.10.1 requires numpy<1.22,>=1.21.0, but you have numpy 1.19.5 which is incompatible.
# sktime 0.10.1 requires scikit-learn>=0.24.0, but you have scikit-learn 0.23.2 which is incompatible.
# pycaret-ts-alpha 3.0.0.dev1649017462 requires imbalanced-learn>=0.8.1, but you have imbalanced-learn 0.7.0 which is incompatible.
# pycaret-ts-alpha 3.0.0.dev1649017462 requires numba~=0.55.0, but you have numba 0.54.1 which is incompatible.
# pycaret-ts-alpha 3.0.0.dev1649017462 requires numpy~=1.21, but you have numpy 1.19.5 which is incompatible.
# pycaret-ts-alpha 3.0.0.dev1649017462 requires scikit-learn>=1.0.2, but you have scikit-learn 0.23.2 which is incompatible.
# pycaret-ts-alpha 3.0.0.dev1649017462 requires scipy~=1.7.3, but you have scipy 1.5.4 which is incompatible.
# pycaret-ts-alpha 3.0.0.dev1649017462 requires yellowbrick>=1.4, but you have yellowbrick 1.3.post1 which is incompatible.
# pmdarima 2.0.2 requires numpy>=1.21.2, but you have numpy 1.19.5 which is incompatible.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 12
#      10 except ModuleNotFoundError:
#      11     get_ipython().system('pip install pycaret')
# ---> 12     what_is_installed()
#
# Cell In[1], line 5, in what_is_installed()
#       4 def what_is_installed():
# ----> 5     from pycaret import show_versions
#       6     show_versions()
#
# File c:\dic\dic\kc\pycaret.py:14
#       9 from pycaret import *
#      10 # from pycaret import show_versions
#      11
#      12 # print(pycaret.show_versions())
# ---> 14 from pycaret.datasets import get_data
#      15 data = get_data('iris')
#      17 # 분류 모델 생성
#
# ModuleNotFoundError: No module named 'pycaret.datasets'; 'pycaret' is not a package
