# %% [markdown]
# # **Support Vector Regression**

# %%
# %matplotlib inline
import numpy as np
from sklearn.svm import SVR
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedShuffleSplit, GridSearchCV, train_test_split

# %%
# np.random.rand(n,m): nxm matrix (0~1)
np.random.rand(40, 1)
# Out:
# array([[0.36669758],
#        [0.14007874],
#        [0.6336327 ],
#        [0.49047905],
#        [0.39428363],
#        [0.9486799 ],
#        [0.99409183],
#        [0.48222234],
#        [0.95730745],
#        [0.15226   ],
#        [0.7128831 ],
#        [0.53195688],
#        [0.70795493],
#        [0.61825582],
#        [0.81617856],
#        [0.79499501],
#        [0.3792775 ],
#        [0.68880089],
#        [0.07144895],
#        [0.10848056],
#        [0.11793458],
#        [0.32664125],
#        [0.12235737],
#        [0.76333265],
#        [0.5373271 ],
#        [0.34478047],
#        [0.25310927],
#        [0.21405576],
#        [0.14475487],
#        [0.5685343 ],
#        [0.51298247],
#        [0.4300045 ],
#        [0.81954827],
#        [0.29739402],
#        [0.59473329],
#        [0.29048479],
#        [0.41112496],
#        [0.13816566],
#        [0.03504627],
#        [0.49635194]])

# %%
# Generate sample data
X = np.sort(5 * np.random.rand(40, 1), axis=0)
X
# Out:
# array([[0.16627782],
#        [0.3253944 ],
#        [0.53434602],
#        [0.6695505 ],
#        [0.72188975],
#        [0.83195355],
#        [0.83432435],
#        [1.00773472],
#        [1.035286  ],
#        [1.12541637],
#        [1.57141421],
#        [1.59828269],
#        [1.99214357],
#        [2.00626782],
#        [2.03186236],
#        [2.07884485],
#        [2.17385243],
#        [2.30940989],
#        [2.32803551],
#        [2.49782455],
#        [2.52676269],
#        [2.5658699 ],
#        [2.65544485],
#        [2.70149322],
#        [2.72008777],
#        [3.12057995],
#        [3.20595057],
#        [3.39649899],
#        [3.39931185],
#        [3.67898854],
#        [3.71974863],
#        [4.07355467],
#        [4.1815473 ],
#        [4.32996172],
#        [4.34811475],
#        [4.41264933],
#        [4.4209407 ],
#        [4.56499868],
#        [4.74614952],
#        [4.77492351]])

# %%
y = np.sin(X).ravel()
y
# Out:
# array([ 0.16551267,  0.31968252,  0.50927834,  0.62063359,  0.66080422,
#         0.73924837,  0.74084286,  0.84562486,  0.86000833,  0.90244705,
#         0.99999981,  0.99962227,  0.91253876,  0.90667125,  0.89557873,
#         0.87369551,  0.82360616,  0.7394027 ,  0.72673523,  0.60021358,
#         0.57681963,  0.54444118,  0.46722349,  0.42602943,  0.40913408,
#         0.02101116, -0.0643135 , -0.25215478, -0.25487574, -0.51190068,
#        -0.54648055, -0.80279136, -0.86238127, -0.92776158, -0.93438258,
#        -0.9554134 , -0.95782873, -0.9891577 , -0.99943017, -0.99804535])

# %%
y[::5]
# Out:
# array([ 0.16551267,  0.73924837,  0.99999981,  0.87369551,  0.57681963,
#         0.02101116, -0.54648055, -0.9554134 ])

# %%
# Add noise to targets
y[::5] += 3 * (0.5 - np.random.rand(8))
y
# Out:
# array([ 1.63010576,  0.31968252,  0.50927834,  0.62063359,  0.66080422,
#         1.25821907,  0.74084286,  0.84562486,  0.86000833,  0.90244705,
#         0.52288372,  0.99962227,  0.91253876,  0.90667125,  0.89557873,
#         1.20332328,  0.82360616,  0.7394027 ,  0.72673523,  0.60021358,
#        -0.42545648,  0.54444118,  0.46722349,  0.42602943,  0.40913408,
#        -0.914828  , -0.0643135 , -0.25215478, -0.25487574, -0.51190068,
#        -0.33978343, -0.80279136, -0.86238127, -0.92776158, -0.93438258,
#        -2.06978393, -0.95782873, -0.9891577 , -0.99943017, -0.99804535])

# %%
# Fit regression model
svr_lin = SVR(kernel='linear', C=1e3)
svr_poly = SVR(kernel='poly', C=1e3, degree=2)
svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1)

y_lin = svr_lin.fit(X, y).predict(X)
y_poly = svr_poly.fit(X, y).predict(X)
y_rbf = svr_rbf.fit(X, y).predict(X)

# %%
# Look at the results
plt.figure(figsize=(9,7))
lw = 2
plt.scatter(X, y, color='darkorange', label='data')
plt.plot(X, y_rbf, color='navy', lw=lw, label='RBF model')
plt.plot(X, y_lin, color='c', lw=lw, label='Linear model')
plt.plot(X, y_poly, color='cornflowerblue', lw=lw, label='Polynomial model')
plt.xlabel('data')
plt.ylabel('target')
plt.title('Support Vector Regression')
plt.legend()

# %% [markdown]
# - **Sinusoid dataset**
#     - 좀 더 복잡한 데이터에 대해서 fitting에 보도록 하겠습니다.

# %%
plt.figure(figsize=(9,7))
N = 200 # number of data points
x = np.linspace(0, 4*np.pi, N)
y = 3.0*np.sin(x+0.001) + 0.5 + np.random.randn(N) # create artificial data with noise
plt.scatter(x, y)

# %%
x[0:5]
# Out:
# array([0.        , 0.06314759, 0.12629518, 0.18944277, 0.25259036])

# %% [markdown]
# - input shape (1,) -> (1,1)

# %%
x=x.reshape(-1,1)
x[0:5]
# Out:
# array([[0.        ],
#        [0.06314759],
#        [0.12629518],
#        [0.18944277],
#        [0.25259036]])

# %%
# Fit regression model
svr_lin = SVR(kernel='linear', C=1e3)
svr_poly = SVR(kernel='poly', C=1e3, degree=2, epsilon = 0.1)
svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1, epsilon = 0.1)

y_lin = svr_lin.fit(x, y).predict(x)
y_poly = svr_poly.fit(x, y).predict(x)
y_rbf = svr_rbf.fit(x, y).predict(x)

# %%
# Look at the results
plt.figure(figsize=(9,7))

lw = 2
plt.scatter(x, y, color='darkorange', label='data')
plt.plot(x, y_rbf, color='navy', lw=lw, label='RBF model')
plt.plot(x, y_lin, color='c', lw=lw, label='Linear model')
plt.plot(x, y_poly, color='cornflowerblue', lw=lw, label='Polynomial model')

plt.xlabel('data')
plt.ylabel('target')
plt.title('Support Vector Regression')
plt.legend()

# %% [markdown]
# # **SVR hyperparameters**

# %% [markdown]
# <p align="center"><img width="600" height="auto" src="./images/svr.png"></p>

# %% [markdown]
# **param1: $\varepsilon$**

# %% [markdown]
# $(-\varepsilon, + \varepsilon)$ 사이에 있는 error는 0으로 취급

# %% [markdown]
# **param2:** $C \rightarrow$ margin $\xi$

# %% [markdown]
# margin $\xi$에 penalty $C$가 곱해져 목적함수에 더 해짐

# %% [markdown]
# $$ \frac{1}{2} ||w||^{2} + C \sum_{i=1}^{l}(\xi_i + \xi_i^{*})$$

# %% [markdown]
# **param3: $\gamma$**$\rightarrow$ kernel function RBF

# %% [markdown]
# $$ k(x,x^{'}) = \frac{\exp(-{||x-x^{'}||}^2)}{\sigma} = \exp(-\gamma{||x-x^{'}||}^2)$$

# %% [markdown]
# - grid search

# %%
parameters = {'kernel':['rbf'] ,
              'C':np.logspace(-1,1,2),
              'gamma': np.logspace(-1,1,2),
              'epsilon':np.logspace(-1,1,2)}
parameters
# Out:
# {'kernel': ['rbf'],
#  'C': array([ 0.1, 10. ]),
#  'gamma': array([ 0.1, 10. ]),
#  'epsilon': array([ 0.1, 10. ])}

# %%
svr = SVR() 
clf = GridSearchCV(estimator=svr, param_grid=parameters)

# %%
clf.fit(x,y)
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': array([ 0.1, 10. ]),
#                          'epsilon': array([ 0.1, 10. ]),
#                          'gamma': array([ 0.1, 10. ]), 'kernel': ['rbf']})

# %%
clf.best_params_
# Out:
# {'C': 10.0, 'epsilon': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}

# %% [markdown]
# - best model

# %%
svr = SVR(kernel='rbf', 
          C=clf.best_params_['C'],
          epsilon=clf.best_params_['epsilon'], 
          gamma = clf.best_params_['gamma'])
svr.fit(x,y)
# Out:
# SVR(C=10.0, gamma=0.1)

# %%
pred_y = svr.predict(x)

# %%
# Look at the results
plt.figure(figsize=(9,7))

lw = 2
plt.scatter(x, y, color='darkorange', label='data')
plt.plot(x, pred_y, color='navy', lw=lw, label='RBF model')

plt.xlabel('data')
plt.ylabel('target')
plt.title('Support Vector Regression')
plt.legend()

# %% [markdown]
# ---
